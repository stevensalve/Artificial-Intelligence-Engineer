# %% [markdown]
# ### Load tensorflow

# %%
import tensorflow as tf
tf.reset_default_graph()
tf.set_random_seed(42)

# %% [markdown]
# ### Read training and test data

# %%
import pandas as pd
train_df = pd.read_csv('data/flower_photos/train.csv')
test_df = pd.read_csv('data/flower_photos/test.csv')

# %%
#Get class names
class_names = train_df['class'].unique().tolist()
print('Flower classes: ', class_names)
# Out:
# Flower classes:  ['tulips', 'daisy', 'sunflowers', 'dandelion', 'roses']

# %%
#Define some parameters
img_size = 60
img_depth = 3

# %% [markdown]
# ### Build batch generator

# %%
import numpy as np

# %%
def batch_generator(df, batchsize=32):   
    
    while True:       
                
        #Generate random numbers to pick images from dataset
        batch_nums = np.random.randint(0,df.shape[0], batchsize)
        
        #Initialize batch images array
        batch_images = np.zeros((batchsize,img_size, img_size,img_depth))
        
        #Initiate batch label array
        batch_labels = np.zeros((batchsize, len(class_names)))
        
        for i in range(batchsize):
            
            #Load image
            flower_image =  tf.keras.preprocessing.image.load_img('data/' + 
                                                                  df.loc[batch_nums[i]]['image_file'],
                                                                  target_size=(img_size, img_size))
            #Convert to array
            flower_image = tf.keras.preprocessing.image.img_to_array(flower_image)
            
            #Get the class
            img_class = df.loc[batch_nums[i]]['class']
            #Conver class to number
            img_class = class_names.index(img_class)
            #Convert class to one hot encoding
            img_class = tf.keras.utils.to_categorical(img_class, num_classes=len(class_names))
            
            #Update batch images and class arrays
            batch_images[i] = flower_image
            batch_labels[i] = img_class        
        
        yield batch_images, batch_labels

# %% [markdown]
# ### Build CNN Model

# %%
#Initialize model, reshape & normalize data
model = tf.keras.models.Sequential()

#Add Layers
model.add(tf.keras.layers.BatchNormalization(input_shape=(img_size,img_size,3,)))
model.add(tf.keras.layers.Conv2D(32, kernel_size=(3,3), activation='relu'))
model.add(tf.keras.layers.Conv2D(64, kernel_size=(3,3), activation='relu'))
model.add(tf.keras.layers.MaxPool2D(pool_size=(2,2)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dropout(0.25))
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax'))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0802 07:39:27.026725 140641621518208 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization (BatchNo (None, 60, 60, 3)         12
# _________________________________________________________________
# conv2d (Conv2D)              (None, 58, 58, 32)        896
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 56, 56, 64)        18496
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 28, 28, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 50176)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               6422656
# _________________________________________________________________
# dropout (Dropout)            (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 5)                 645
# =================================================================
# Total params: 6,442,705
# Trainable params: 6,442,699
# Non-trainable params: 6
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
#Create train and test generator
batchsize = 64
train_generator = batch_generator(train_df, batchsize=batchsize) #batchsize can be changed
test_generator = batch_generator(test_df, batchsize=batchsize)

# %%
model.fit_generator(train_generator, 
                          epochs=50,
                          steps_per_epoch= train_df.shape[0]//batchsize,
                          validation_data=test_generator,
                          validation_steps = test_df.shape[0]//batchsize)
# Out:
# Epoch 1/50
# 45/45 [==============================] - 14s 303ms/step - loss: 2.1883 - acc: 0.2976 - val_loss: 1.6107 - val_acc: 0.3026
# Epoch 2/50
# 45/45 [==============================] - 10s 225ms/step - loss: 1.3272 - acc: 0.4344 - val_loss: 1.2650 - val_acc: 0.4460
# Epoch 3/50
# 45/45 [==============================] - 10s 226ms/step - loss: 1.2225 - acc: 0.5090 - val_loss: 1.1633 - val_acc: 0.4972
# Epoch 4/50
# 45/45 [==============================] - 10s 226ms/step - loss: 1.0113 - acc: 0.6066 - val_loss: 1.0391 - val_acc: 0.5724
# Epoch 5/50
# 45/45 [==============================] - 10s 227ms/step - loss: 0.8684 - acc: 0.6778 - val_loss: 1.0081 - val_acc: 0.5895
# Epoch 6/50
# 45/45 [==============================] - 10s 232ms/step - loss: 0.7140 - acc: 0.7437 - val_loss: 0.9976 - val_acc: 0.6094
# Epoch 7/50
# 45/45 [==============================] - 10s 229ms/step - loss: 0.5422 - acc: 0.8076 - val_loss: 1.0089 - val_acc: 0.6321
# Epoch 8/50
# 45/45 [==============================] - 10s 227ms/step - loss: 0.4036 - acc: 0.8635 - val_loss: 1.0978 - val_acc: 0.5866
# Epoch 9/50
# 45/45 [==============================] - 10s 230ms/step - loss: 0.3078 - acc: 0.9076 - val_loss: 1.1872 - val_acc: 0.5682
# Epoch 10/50
# 45/45 [==============================] - 10s 227ms/step - loss: 0.2255 - acc: 0.9306 - val_loss: 1.2956 - val_acc: 0.6378
# Epoch 11/50
# 45/45 [==============================] - 10s 232ms/step - loss: 0.1526 - acc: 0.9528 - val_loss: 1.3092 - val_acc: 0.6136
# Epoch 12/50
# 45/45 [==============================] - 10s 228ms/step - loss: 0.1275 - acc: 0.9615 - val_loss: 1.4203 - val_acc: 0.6108
# Epoch 13/50
# 45/45 [==============================] - 10s 231ms/step - loss: 0.0904 - acc: 0.9747 - val_loss: 1.4617 - val_acc: 0.5881
# Epoch 14/50
# 45/45 [==============================] - 10s 229ms/step - loss: 0.0917 - acc: 0.9764 - val_loss: 1.7930 - val_acc: 0.6136
# Epoch 15/50
# 45/45 [==============================] - 10s 233ms/step - loss: 0.0720 - acc: 0.9823 - val_loss: 1.6267 - val_acc: 0.6165
# Epoch 16/50
# 45/45 [==============================] - 10s 230ms/step - loss: 0.0790 - acc: 0.9774 - val_loss: 1.8084 - val_acc: 0.6009
# Epoch 17/50
# 45/45 [==============================] - 10s 229ms/step - loss: 0.0501 - acc: 0.9868 - val_loss: 1.6560 - val_acc: 0.5966
# Epoch 18/50
# 45/45 [==============================] - 10s 232ms/step - loss: 0.0436 - acc: 0.9882 - val_loss: 1.7997 - val_acc: 0.6364
# Epoch 19/50
# 45/45 [==============================] - 11s 235ms/step - loss: 0.0438 - acc: 0.9872 - val_loss: 1.7063 - val_acc: 0.6605
# Epoch 20/50
# 45/45 [==============================] - 10s 233ms/step - loss: 0.0394 - acc: 0.9913 - val_loss: 1.7204 - val_acc: 0.6364
# Epoch 21/50
# 45/45 [==============================] - 11s 235ms/step - loss: 0.0345 - acc: 0.9913 - val_loss: 1.9805 - val_acc: 0.6094
# Epoch 22/50
# 45/45 [==============================] - 11s 235ms/step - loss: 0.0437 - acc: 0.9889 - val_loss: 1.7909 - val_acc: 0.6193
# Epoch 23/50
# 45/45 [==============================] - 10s 230ms/step - loss: 0.0306 - acc: 0.9910 - val_loss: 1.9607 - val_acc: 0.6165
# Epoch 24/50
# 45/45 [==============================] - 10s 231ms/step - loss: 0.0340 - acc: 0.9913 - val_loss: 2.1067 - val_acc: 0.6051
# Epoch 25/50
# 45/45 [==============================] - 11s 233ms/step - loss: 0.0258 - acc: 0.9937 - val_loss: 2.2558 - val_acc: 0.6250
# Epoch 26/50
# 45/45 [==============================] - 11s 235ms/step - loss: 0.0215 - acc: 0.9951 - val_loss: 2.1050 - val_acc: 0.6051
# Epoch 27/50
# 45/45 [==============================] - 10s 232ms/step - loss: 0.0216 - acc: 0.9941 - val_loss: 2.2149 - val_acc: 0.6151
# Epoch 28/50
# 45/45 [==============================] - 10s 230ms/step - loss: 0.0221 - acc: 0.9955 - val_loss: 2.2110 - val_acc: 0.6293
# Epoch 29/50
# 45/45 [==============================] - 11s 236ms/step - loss: 0.0267 - acc: 0.9913 - val_loss: 2.0424 - val_acc: 0.6477
# Epoch 30/50
# 45/45 [==============================] - 10s 232ms/step - loss: 0.0189 - acc: 0.9948 - val_loss: 2.1833 - val_acc: 0.6392
# Epoch 31/50
# 45/45 [==============================] - 11s 233ms/step - loss: 0.0219 - acc: 0.9948 - val_loss: 2.2039 - val_acc: 0.6747
# Epoch 32/50
# 45/45 [==============================] - 10s 231ms/step - loss: 0.0307 - acc: 0.9882 - val_loss: 1.9932 - val_acc: 0.6179
# Epoch 33/50
# 45/45 [==============================] - 10s 233ms/step - loss: 0.0260 - acc: 0.9917 - val_loss: 2.2459 - val_acc: 0.6193
# Epoch 34/50
# 45/45 [==============================] - 11s 236ms/step - loss: 0.0208 - acc: 0.9944 - val_loss: 2.3390 - val_acc: 0.5952
# Epoch 35/50
# 45/45 [==============================] - 11s 238ms/step - loss: 0.0171 - acc: 0.9951 - val_loss: 2.3301 - val_acc: 0.6193
# Epoch 36/50
# 45/45 [==============================] - 11s 237ms/step - loss: 0.0241 - acc: 0.9927 - val_loss: 2.6826 - val_acc: 0.5895
# Epoch 37/50
# 45/45 [==============================] - 11s 237ms/step - loss: 0.0192 - acc: 0.9948 - val_loss: 2.3445 - val_acc: 0.6236
# Epoch 38/50
# 45/45 [==============================] - 11s 239ms/step - loss: 0.0200 - acc: 0.9934 - val_loss: 2.3323 - val_acc: 0.6122
# Epoch 39/50
# 45/45 [==============================] - 11s 235ms/step - loss: 0.0144 - acc: 0.9969 - val_loss: 2.5581 - val_acc: 0.6534
# Epoch 40/50
# 45/45 [==============================] - 10s 232ms/step - loss: 0.0354 - acc: 0.9931 - val_loss: 2.3444 - val_acc: 0.6179
# Epoch 41/50
# 45/45 [==============================] - 11s 238ms/step - loss: 0.0326 - acc: 0.9913 - val_loss: 2.5245 - val_acc: 0.6307
# Epoch 42/50
# 45/45 [==============================] - 11s 237ms/step - loss: 0.0274 - acc: 0.9924 - val_loss: 2.5240 - val_acc: 0.5866
# Epoch 43/50
# 45/45 [==============================] - 11s 234ms/step - loss: 0.0188 - acc: 0.9931 - val_loss: 2.5730 - val_acc: 0.6009
# Epoch 44/50
# 45/45 [==============================] - 11s 238ms/step - loss: 0.0218 - acc: 0.9927 - val_loss: 2.2971 - val_acc: 0.6264
# Epoch 45/50
# 45/45 [==============================] - 10s 233ms/step - loss: 0.0118 - acc: 0.9965 - val_loss: 2.1577 - val_acc: 0.6506
# Epoch 46/50
# 45/45 [==============================] - 11s 235ms/step - loss: 0.0144 - acc: 0.9955 - val_loss: 2.1608 - val_acc: 0.6520
# Epoch 47/50
# 45/45 [==============================] - 11s 235ms/step - loss: 0.0166 - acc: 0.9972 - val_loss: 2.9243 - val_acc: 0.6264
# Epoch 48/50
# 45/45 [==============================] - 10s 232ms/step - loss: 0.0132 - acc: 0.9965 - val_loss: 2.4508 - val_acc: 0.6293
# Epoch 49/50
# 45/45 [==============================] - 11s 237ms/step - loss: 0.0276 - acc: 0.9899 - val_loss: 3.0549 - val_acc: 0.5795
# Epoch 50/50
# 45/45 [==============================] - 11s 236ms/step - loss: 0.0206 - acc: 0.9934 - val_loss: 2.7916 - val_acc: 0.6278
