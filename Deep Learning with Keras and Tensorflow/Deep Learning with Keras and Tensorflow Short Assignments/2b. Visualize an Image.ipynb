# %% [markdown]
# ### Check Image data on disk

# %%
#Check out few file names for the photos - 

#for Linux uncomment the following line
# !ls data/flower_photos/daisy | head -3

#For windows, uncomment the following line
#!dir data\flower_photos\daisy /a-d
# Out:
# 100080576_f52e8ee070_n.jpg
# 10140303196_b88d3d6cec.jpg
# 10172379554_b296050f82_n.jpg

# %%
import tensorflow as tf
tf.reset_default_graph()

# %% [markdown]
# #### Load image from the disk

# %%
#Load an image using Keras image class
image_file = 'data/flower_photos/daisy/100080576_f52e8ee070_n.jpg'
flower_image = tf.keras.preprocessing.image.load_img(image_file)

#Inspect image
flower_image
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=320x263 at 0x7FF2B4546B00>

# %% [markdown]
# <font size="2">Keras image class is a wrapper for PIL Image class</font>

# %%
#Lets check the class type for Keras image
type(flower_image)
# Out:
# PIL.JpegImagePlugin.JpegImageFile

# %%
flower_image2 = tf.keras.preprocessing.image.load_img('data/flower_photos/daisy/10140303196_b88d3d6cec.jpg')

# %%
flower_image2
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=500x313 at 0x7FF2B44D90F0>

# %% [markdown]
# ### Image Size

# %%
#Size of the image
flower_image.size
# Out:
# (320, 263)

# %%
#Size of 2nd image
flower_image2.size
# Out:
# (500, 313)

# %%
#Resizing image
flower_image = flower_image.resize([128,128])

# %%
flower_image
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FF2B44D9080>

# %% [markdown]
# ### Converting image to numpy array for ML

# %%
flower_array = tf.keras.preprocessing.image.img_to_array(flower_image)
print('Shape of numpy array', flower_array.shape)
# Out:
# Shape of numpy array (128, 128, 3)

# %%
#Check the contents of the array
flower_array
# Out:
# array([[[137., 137., 135.],
#         [144., 144., 144.],
#         [148., 148., 148.],
#         ...,
#         [154., 154., 152.],
#         [154., 154., 152.],
#         [156., 156., 156.]],
#
#        [[136., 136., 134.],
#         [143., 143., 141.],
#         [147., 147., 147.],
#         ...,
#         [155., 155., 153.],
#         [152., 152., 150.],
#         [153., 153., 153.]],
#
#        [[134., 133., 129.],
#         [141., 140., 138.],
#         [146., 145., 143.],
#         ...,
#         [158., 158., 156.],
#         [151., 151., 149.],
#         [151., 151., 151.]],
#
#        ...,
#
#        [[ 43.,  46.,  25.],
#         [ 43.,  46.,  25.],
#         [ 43.,  46.,  25.],
#         ...,
#         [129., 125., 124.],
#         [127., 123., 122.],
#         [130., 126., 125.]],
#
#        [[ 44.,  47.,  26.],
#         [ 44.,  47.,  26.],
#         [ 45.,  48.,  27.],
#         ...,
#         [132., 128., 127.],
#         [130., 126., 125.],
#         [130., 126., 125.]],
#
#        [[ 44.,  47.,  26.],
#         [ 44.,  47.,  26.],
#         [ 45.,  48.,  27.],
#         ...,
#         [133., 129., 128.],
#         [131., 127., 126.],
#         [130., 126., 125.]]], dtype=float32)

# %% [markdown]
# ### Converting numpy array to image

# %%
new_image = tf.keras.preprocessing.image.array_to_img(flower_array)

#Show image
new_image
# Out:
# <PIL.Image.Image image mode=RGB size=128x128 at 0x7FF2DB2DB2B0>
