# %% [markdown]
# ### Load tensorflow

# %%
import tensorflow as tf
tf.reset_default_graph()
tf.set_random_seed(42)

# %% [markdown]
# ### Read training and test data

# %%
import pandas as pd
train_df = pd.read_csv('data/flower_photos/train.csv')
test_df = pd.read_csv('data/flower_photos/test.csv')

# %%
#Get class names
class_names = train_df['class'].unique().tolist()
print('Flower classes: ', class_names)
# Out:
# Flower classes:  ['tulips', 'daisy', 'sunflowers', 'dandelion', 'roses']

# %%
#Define some parameters
img_size = 60
img_depth = 3

# %% [markdown]
# ### Build batch generator

# %%
import numpy as np

# %%
def batch_generator(df, batchsize=32, train_mode=True):   
    
    img_generator= tf.keras.preprocessing.image.ImageDataGenerator(rotation_range=20,
                                                                   width_shift_range=0.2,
                                                                   height_shift_range=0.2,
                                                                   horizontal_flip=True)
    
    while True:       
        
        
        #Generate random numbers to pick images from dataset
        batch_nums = np.random.randint(0,df.shape[0],batchsize)
        
        #Initialize batch images array
        batch_images = np.zeros((batchsize,img_size, img_size,img_depth))
        
        #Initiate batch label array
        batch_labels = np.zeros((batchsize, len(class_names)))
        
        for i in range(batchsize):
            
            #Load image
            flower_image =  tf.keras.preprocessing.image.load_img('data/' + 
                                                                  df.loc[batch_nums[i]]['image_file'],
                                                                  target_size=(img_size, img_size))
            #Convert to array
            flower_image = tf.keras.preprocessing.image.img_to_array(flower_image)
            
            if(train_mode):
                #Apply transform
                flower_image =  img_generator.random_transform(flower_image)
            
            
            #Get the class
            img_class = df.loc[batch_nums[i]]['class']
            #Conver class to number
            img_class = class_names.index(img_class)
            #Convert class to one hot encoding
            img_class = tf.keras.utils.to_categorical(img_class, num_classes=len(class_names))
            
            #Update batch images and class arrays
            batch_images[i] = flower_image
            batch_labels[i] = img_class        
        
        yield batch_images, batch_labels

# %% [markdown]
# ### Build CNN Model

# %%
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.BatchNormalization(input_shape=(img_size,img_size,3,)))
model.add(tf.keras.layers.Conv2D(32, kernel_size=(3,3), activation='relu'))
model.add(tf.keras.layers.Conv2D(64, kernel_size=(3,3), activation='relu'))
model.add(tf.keras.layers.MaxPool2D(pool_size=(2,2)))
model.add(tf.keras.layers.Flatten())
model.add(tf.keras.layers.Dense(128, activation='relu'))
model.add(tf.keras.layers.Dropout(0.25))

#Output layer
model.add(tf.keras.layers.Dense(len(class_names), activation='softmax'))
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0801 20:43:28.136089 139705549719424 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %%
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### Train the model

# %%
#Create train and test generator
batchsize = 64
train_generator = batch_generator(train_df, batchsize=batchsize) #batchsize can be changed
test_generator = batch_generator(test_df, batchsize=batchsize, train_mode=False)

# %%
model.fit_generator(train_generator, 
                          epochs=50,
                          steps_per_epoch= train_df.shape[0]//batchsize,
                          validation_data=test_generator,
                          validation_steps = test_df.shape[0]//batchsize)
# Out:
# Epoch 1/50
# 45/45 [==============================] - 17s 376ms/step - loss: 1.7677 - acc: 0.4049 - val_loss: 1.5056 - val_acc: 0.4403
# Epoch 2/50
# 45/45 [==============================] - 13s 295ms/step - loss: 1.2121 - acc: 0.4903 - val_loss: 1.2243 - val_acc: 0.4844
# Epoch 3/50
# 45/45 [==============================] - 13s 286ms/step - loss: 1.1106 - acc: 0.5437 - val_loss: 0.9998 - val_acc: 0.5625
# Epoch 4/50
# 45/45 [==============================] - 13s 293ms/step - loss: 1.0726 - acc: 0.5778 - val_loss: 1.0739 - val_acc: 0.5952
# Epoch 5/50
# 45/45 [==============================] - 13s 288ms/step - loss: 1.0013 - acc: 0.6167 - val_loss: 0.8939 - val_acc: 0.6477
# Epoch 6/50
# 45/45 [==============================] - 13s 288ms/step - loss: 0.9563 - acc: 0.6361 - val_loss: 0.8925 - val_acc: 0.6250
# Epoch 7/50
# 45/45 [==============================] - 13s 289ms/step - loss: 0.9120 - acc: 0.6392 - val_loss: 0.9153 - val_acc: 0.6534
# Epoch 8/50
# 45/45 [==============================] - 13s 283ms/step - loss: 0.8772 - acc: 0.6628 - val_loss: 0.8246 - val_acc: 0.6918
# Epoch 9/50
# 45/45 [==============================] - 13s 288ms/step - loss: 0.8523 - acc: 0.6806 - val_loss: 0.8468 - val_acc: 0.6747
# Epoch 10/50
# 45/45 [==============================] - 13s 289ms/step - loss: 0.8535 - acc: 0.6868 - val_loss: 0.8062 - val_acc: 0.7173
# Epoch 11/50
# 45/45 [==============================] - 13s 288ms/step - loss: 0.7950 - acc: 0.6851 - val_loss: 0.7669 - val_acc: 0.7116
# Epoch 12/50
# 45/45 [==============================] - 13s 286ms/step - loss: 0.8136 - acc: 0.6868 - val_loss: 0.7111 - val_acc: 0.7358
# Epoch 13/50
# 45/45 [==============================] - 13s 287ms/step - loss: 0.7896 - acc: 0.6948 - val_loss: 0.8189 - val_acc: 0.7045
# Epoch 14/50
# 45/45 [==============================] - 13s 282ms/step - loss: 0.7427 - acc: 0.7260 - val_loss: 0.7472 - val_acc: 0.7173
# Epoch 15/50
# 45/45 [==============================] - 13s 286ms/step - loss: 0.7496 - acc: 0.7160 - val_loss: 0.6817 - val_acc: 0.7429
# Epoch 16/50
# 45/45 [==============================] - 13s 290ms/step - loss: 0.7596 - acc: 0.7111 - val_loss: 0.7818 - val_acc: 0.6889
# Epoch 17/50
# 45/45 [==============================] - 13s 286ms/step - loss: 0.7167 - acc: 0.7299 - val_loss: 0.7375 - val_acc: 0.7301
# Epoch 18/50
# 45/45 [==============================] - 13s 292ms/step - loss: 0.7188 - acc: 0.7257 - val_loss: 0.7048 - val_acc: 0.7273
# Epoch 19/50
# 45/45 [==============================] - 13s 286ms/step - loss: 0.6860 - acc: 0.7441 - val_loss: 0.7456 - val_acc: 0.7457
# Epoch 20/50
# 45/45 [==============================] - 13s 284ms/step - loss: 0.7277 - acc: 0.7278 - val_loss: 0.6797 - val_acc: 0.7614
# Epoch 21/50
# 45/45 [==============================] - 13s 293ms/step - loss: 0.6861 - acc: 0.7476 - val_loss: 0.6713 - val_acc: 0.7415
# Epoch 22/50
# 45/45 [==============================] - 13s 291ms/step - loss: 0.6766 - acc: 0.7441 - val_loss: 0.7151 - val_acc: 0.7230
# Epoch 23/50
# 45/45 [==============================] - 13s 284ms/step - loss: 0.7072 - acc: 0.7372 - val_loss: 0.7117 - val_acc: 0.7543
# Epoch 24/50
# 45/45 [==============================] - 13s 287ms/step - loss: 0.6676 - acc: 0.7396 - val_loss: 0.7013 - val_acc: 0.7670
# Epoch 25/50
# 45/45 [==============================] - 13s 284ms/step - loss: 0.6468 - acc: 0.7597 - val_loss: 0.7997 - val_acc: 0.7074
# Epoch 26/50
# 45/45 [==============================] - 13s 295ms/step - loss: 0.6581 - acc: 0.7472 - val_loss: 0.7273 - val_acc: 0.7330
# Epoch 27/50
# 45/45 [==============================] - 13s 289ms/step - loss: 0.6670 - acc: 0.7472 - val_loss: 0.6698 - val_acc: 0.7798
# Epoch 28/50
# 45/45 [==============================] - 13s 288ms/step - loss: 0.6501 - acc: 0.7556 - val_loss: 0.8249 - val_acc: 0.7188
# Epoch 29/50
# 45/45 [==============================] - 13s 292ms/step - loss: 0.6246 - acc: 0.7694 - val_loss: 0.7186 - val_acc: 0.7344
# Epoch 30/50
# 45/45 [==============================] - 13s 291ms/step - loss: 0.6246 - acc: 0.7566 - val_loss: 0.7222 - val_acc: 0.7486
# Epoch 31/50
# 45/45 [==============================] - 13s 287ms/step - loss: 0.6390 - acc: 0.7545 - val_loss: 0.8381 - val_acc: 0.7259
# Epoch 32/50
# 45/45 [==============================] - 15s 341ms/step - loss: 0.6490 - acc: 0.7448 - val_loss: 0.6923 - val_acc: 0.7543
# Epoch 33/50
# 45/45 [==============================] - 13s 297ms/step - loss: 0.6252 - acc: 0.7545 - val_loss: 0.7352 - val_acc: 0.7330
# Epoch 34/50
# 45/45 [==============================] - 13s 290ms/step - loss: 0.6182 - acc: 0.7642 - val_loss: 0.7426 - val_acc: 0.7315
# Epoch 35/50
# 45/45 [==============================] - 13s 283ms/step - loss: 0.6459 - acc: 0.7653 - val_loss: 0.7146 - val_acc: 0.7273
# Epoch 36/50
# 45/45 [==============================] - 13s 284ms/step - loss: 0.6015 - acc: 0.7826 - val_loss: 0.7022 - val_acc: 0.7429
# Epoch 37/50
# 45/45 [==============================] - 13s 286ms/step - loss: 0.5854 - acc: 0.7771 - val_loss: 0.6430 - val_acc: 0.7599
# Epoch 38/50
# 45/45 [==============================] - 13s 285ms/step - loss: 0.6029 - acc: 0.7792 - val_loss: 0.7122 - val_acc: 0.7585
# Epoch 39/50
# 45/45 [==============================] - 13s 288ms/step - loss: 0.6123 - acc: 0.7594 - val_loss: 0.5736 - val_acc: 0.7784
# Epoch 40/50
# 45/45 [==============================] - 13s 281ms/step - loss: 0.5612 - acc: 0.7885 - val_loss: 0.6649 - val_acc: 0.7628
# Epoch 41/50
# 45/45 [==============================] - 13s 283ms/step - loss: 0.5643 - acc: 0.7816 - val_loss: 0.7338 - val_acc: 0.7571
# Epoch 42/50
# 45/45 [==============================] - 13s 279ms/step - loss: 0.5645 - acc: 0.7809 - val_loss: 0.6940 - val_acc: 0.7514
# Epoch 43/50
# 45/45 [==============================] - 13s 283ms/step - loss: 0.5672 - acc: 0.7896 - val_loss: 0.8868 - val_acc: 0.6847
# Epoch 44/50
# 45/45 [==============================] - 12s 277ms/step - loss: 0.5689 - acc: 0.7878 - val_loss: 0.6266 - val_acc: 0.7571
# Epoch 45/50
# 45/45 [==============================] - 13s 280ms/step - loss: 0.5678 - acc: 0.7913 - val_loss: 0.6924 - val_acc: 0.7557
# Epoch 46/50
# 45/45 [==============================] - 13s 286ms/step - loss: 0.5544 - acc: 0.7903 - val_loss: 0.7654 - val_acc: 0.7457
# Epoch 47/50
# 45/45 [==============================] - 13s 290ms/step - loss: 0.5782 - acc: 0.7812 - val_loss: 0.7208 - val_acc: 0.7358
# Epoch 48/50
# 45/45 [==============================] - 13s 287ms/step - loss: 0.5601 - acc: 0.7861 - val_loss: 0.6470 - val_acc: 0.7585
# Epoch 49/50
# 45/45 [==============================] - 13s 286ms/step - loss: 0.5569 - acc: 0.7892 - val_loss: 0.6549 - val_acc: 0.7670
# Epoch 50/50
# 45/45 [==============================] - 13s 290ms/step - loss: 0.5366 - acc: 0.7997 - val_loss: 0.7385 - val_acc: 0.7386
