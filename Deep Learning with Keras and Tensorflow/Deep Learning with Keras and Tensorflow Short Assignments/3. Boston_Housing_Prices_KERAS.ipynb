# %% [markdown]
# ### Load tensorflow

# %%
import tensorflow as tf
tf.reset_default_graph()

# %% [markdown]
# ### Collect Data

# %%
(features, actual_prices),_ = tf.keras.datasets.boston_housing.load_data(test_split=0)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/boston_housing.npz
# 57344/57026 [==============================] - 0s 0us/step

# %%
print('Number of examples: ', features.shape[0])
print('Number of features for each example: ', features.shape[1])
print('Shape of actual prices data: ', actual_prices.shape)
# Out:
# Number of examples:  506
# Number of features for each example:  13
# Shape of actual prices data:  (506,)

# %% [markdown]
# ### Building the graph in Keras

# %%
#Initialize Sequential Graph (model)
model = tf.keras.models.Sequential()

#Normalize input data
model.add(tf.keras.layers.BatchNormalization(input_shape=(13,)))

#Add Dense layer for prediction - Keras declares weights and bias automatically
model.add(tf.keras.layers.Dense(1))

#Compile the model - add Loss and Gradient Descent optimizer
model.compile(optimizer='sgd', loss='mse')
# Out:
# WARNING: Logging before flag parsing goes to stderr.
# W0801 04:48:11.789222 140104704116608 deprecation.py:506] From /usr/local/lib/python3.6/dist-packages/tensorflow/python/ops/init_ops.py:1251: calling VarianceScaling.__init__ (from tensorflow.python.ops.init_ops) with dtype is deprecated and will be removed in a future version.
# Instructions for updating:
# Call initializer instance with the dtype argument instead of passing it to the constructor

# %% [markdown]
# ### Execute the Graph

# %%
model.fit(features, actual_prices, epochs=100)
# Out:
# Epoch 1/100
# 506/506 [==============================] - 2s 3ms/sample - loss: 179.5098
# Epoch 2/100
# 506/506 [==============================] - 0s 61us/sample - loss: 36.8287
# Epoch 3/100
# 506/506 [==============================] - 0s 60us/sample - loss: 33.4970
# Epoch 4/100
# 506/506 [==============================] - 0s 60us/sample - loss: 32.5473
# Epoch 5/100
# 506/506 [==============================] - 0s 62us/sample - loss: 33.4753
# Epoch 6/100
# 506/506 [==============================] - 0s 61us/sample - loss: 31.0615
# Epoch 7/100
# 506/506 [==============================] - 0s 83us/sample - loss: 32.7253
# Epoch 8/100
# 506/506 [==============================] - 0s 62us/sample - loss: 28.4852
# Epoch 9/100
# 506/506 [==============================] - 0s 62us/sample - loss: 28.7541
# Epoch 10/100
# 506/506 [==============================] - 0s 61us/sample - loss: 27.7182
# Epoch 11/100
# 506/506 [==============================] - 0s 61us/sample - loss: 26.7151
# Epoch 12/100
# 506/506 [==============================] - 0s 61us/sample - loss: 30.1361
# Epoch 13/100
# 506/506 [==============================] - 0s 59us/sample - loss: 25.8745
# Epoch 14/100
# 506/506 [==============================] - 0s 58us/sample - loss: 24.9510
# Epoch 15/100
# 506/506 [==============================] - 0s 63us/sample - loss: 30.0681
# Epoch 16/100
# 506/506 [==============================] - 0s 58us/sample - loss: 29.4143
# Epoch 17/100
# 506/506 [==============================] - 0s 59us/sample - loss: 33.1676
# Epoch 18/100
# 506/506 [==============================] - 0s 59us/sample - loss: 27.1341
# Epoch 19/100
# 506/506 [==============================] - 0s 58us/sample - loss: 27.8735
# Epoch 20/100
# 506/506 [==============================] - 0s 59us/sample - loss: 28.0947
# Epoch 21/100
# 506/506 [==============================] - 0s 57us/sample - loss: 27.3049
# Epoch 22/100
# 506/506 [==============================] - 0s 57us/sample - loss: 28.4110
# Epoch 23/100
# 506/506 [==============================] - 0s 60us/sample - loss: 27.7367
# Epoch 24/100
# 506/506 [==============================] - 0s 59us/sample - loss: 28.3012
# Epoch 25/100
# 506/506 [==============================] - 0s 58us/sample - loss: 26.6411
# Epoch 26/100
# 506/506 [==============================] - 0s 58us/sample - loss: 27.0886
# Epoch 27/100
# Epoch 66/100
# 506/506 [==============================] - 0s 63us/sample - loss: 26.5925
# Epoch 67/100
# 506/506 [==============================] - 0s 64us/sample - loss: 30.5310
# Epoch 68/100
# 506/506 [==============================] - 0s 63us/sample - loss: 29.6936
# Epoch 69/100
# 506/506 [==============================] - 0s 81us/sample - loss: 24.6579
# Epoch 70/100
# 506/506 [==============================] - 0s 62us/sample - loss: 25.8155
# Epoch 71/100
# 506/506 [==============================] - 0s 58us/sample - loss: 33.1580
# Epoch 72/100
# 506/506 [==============================] - 0s 59us/sample - loss: 29.7377
# Epoch 73/100
# 506/506 [==============================] - 0s 63us/sample - loss: 31.1841
# Epoch 74/100
# 506/506 [==============================] - 0s 65us/sample - loss: 30.0240
# Epoch 75/100
# 506/506 [==============================] - 0s 59us/sample - loss: 25.4917
# Epoch 76/100
# 506/506 [==============================] - 0s 63us/sample - loss: 28.4630
# Epoch 77/100
# 506/506 [==============================] - 0s 66us/sample - loss: 26.3445
# Epoch 78/100
# 506/506 [==============================] - 0s 55us/sample - loss: 25.6218
# Epoch 79/100
# 506/506 [==============================] - 0s 57us/sample - loss: 33.1425
# Epoch 80/100
# 506/506 [==============================] - 0s 58us/sample - loss: 32.2006
# Epoch 81/100
# 506/506 [==============================] - 0s 66us/sample - loss: 29.1574
# Epoch 82/100
# 506/506 [==============================] - 0s 72us/sample - loss: 28.5231
# Epoch 83/100
# 506/506 [==============================] - 0s 75us/sample - loss: 28.3369
# Epoch 84/100
# 506/506 [==============================] - 0s 65us/sample - loss: 26.4050
# Epoch 85/100
# 506/506 [==============================] - 0s 59us/sample - loss: 28.5369
# Epoch 86/100
# 506/506 [==============================] - 0s 61us/sample - loss: 25.9180
# Epoch 87/100
# 506/506 [==============================] - 0s 73us/sample - loss: 26.0583
# Epoch 88/100
# 506/506 [==============================] - 0s 58us/sample - loss: 28.2560
# Epoch 89/100
# 506/506 [==============================] - 0s 63us/sample - loss: 29.0891
# Epoch 90/100
# 506/506 [==============================] - 0s 64us/sample - loss: 30.6502
# Epoch 91/100
# 506/506 [==============================] - 0s 68us/sample - loss: 29.4305
# Epoch 92/100
# 506/506 [==============================] - 0s 64us/sample - loss: 26.0239
# Epoch 93/100
# 506/506 [==============================] - 0s 61us/sample - loss: 29.4540
# Epoch 94/100
# 506/506 [==============================] - 0s 63us/sample - loss: 24.0685
# Epoch 95/100
# 506/506 [==============================] - 0s 57us/sample - loss: 28.7684
# Epoch 96/100
# 506/506 [==============================] - 0s 64us/sample - loss: 28.2378
# Epoch 97/100
# 506/506 [==============================] - 0s 67us/sample - loss: 27.8858
# Epoch 98/100
# 506/506 [==============================] - 0s 67us/sample - loss: 29.0581
# Epoch 99/100
# 506/506 [==============================] - 0s 90us/sample - loss: 30.0134
# Epoch 100/100
# 506/506 [==============================] - 0s 61us/sample - loss: 25.1156

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# batch_normalization (BatchNo (None, 13)                52
# _________________________________________________________________
# dense (Dense)                (None, 1)                 14
# =================================================================
# Total params: 66
# Trainable params: 40
# Non-trainable params: 26
# _________________________________________________________________

# %% [markdown]
# ### Save the model

# %%
model.save('boston_housing_lr.h5')

# %%
model.to_json()
